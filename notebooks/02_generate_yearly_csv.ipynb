# %%
from config import DATASET_ROOT, LOG_DIR, PROCESSED_DIR, VARIABLES
from climate_preprocessing.grd import discover_year_files
from climate_preprocessing.csv_export import convert_variable_years_to_csv
from climate_preprocessing.logging_utils import configure_logging

logger = configure_logging(LOG_DIR)
variable = VARIABLES['rainfall']
year_files = discover_year_files(DATASET_ROOT, variable)
convert_variable_years_to_csv(year_files, variable, DATASET_ROOT, PROCESSED_DIR, logger)
