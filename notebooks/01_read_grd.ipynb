# %%
from config import DATASET_ROOT, VARIABLES
from climate_preprocessing.grd import discover_year_files, read_grd_file

variable = VARIABLES['rainfall']
year_file = discover_year_files(DATASET_ROOT, variable)[0]
array = read_grd_file(year_file.path, variable)
array.shape
