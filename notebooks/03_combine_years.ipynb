# %%
from config import DATASET_ROOT, LOG_DIR, PROCESSED_DIR, VARIABLES
from climate_preprocessing.csv_export import combine_yearly_csvs
from climate_preprocessing.logging_utils import configure_logging
from climate_preprocessing.pipeline import get_discovered_years

logger = configure_logging(LOG_DIR)
years = get_discovered_years(DATASET_ROOT)
for variable in VARIABLES.values():
    combine_yearly_csvs(variable, years, PROCESSED_DIR, logger)
