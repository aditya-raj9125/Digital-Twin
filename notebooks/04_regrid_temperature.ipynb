# %%
from config import DATASET_ROOT, VARIABLES
from climate_preprocessing.grd import discover_year_files, read_grd_file
from climate_preprocessing.regrid import interpolate_to_reference_grid

source = VARIABLES['max_temp']
reference = VARIABLES['rainfall']
year_file = discover_year_files(DATASET_ROOT, source)[0]
array = read_grd_file(year_file.path, source)
interpolated = interpolate_to_reference_grid(array, source, reference)
interpolated.shape
